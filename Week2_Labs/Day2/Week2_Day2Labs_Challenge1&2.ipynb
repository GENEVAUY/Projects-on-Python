# %% [markdown]
# Lab | Data Structuring and Combining Data
# Objective:
#
# Combine and integrate data from multiple sources using merging, concatenating, or joining techniques to generate more comprehensive and meaningful datasets for analysis.
# Modify the structure of data by pivoting, stacking/unstacking, or melting dataframes, enabling them to efficiently explore and analyze complex datasets.
# Challenge 1: Combining Data
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
# But this time, we got new data, which can be found in the following 2 CSV files located at the following links:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
# Perform data cleaning and formatting using the main cleaning and formatting function created in the previous lab to clean and format the data.
#
# Combine the data from the three dataframes into a single dataframe, named "customer_data", using appropriate merging, concatenating, and joining techniques.
#
# Verify that the customer_data dataframe contains all the rows and columns from the three original dataframes.
#
# Observation:
#
# One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv")
df2 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv")
df3 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv")

# %%
df1= df1.rename(columns=str.lower)
df2= df2.rename(columns=str.lower)
df3= df3.rename(columns=str.lower)

# %%
def rename_columns(df3):
    df3.rename (columns = {'state':'st'}, inplace=True)
    return df3

# %%
df3 = rename_columns(df3)

# %%
combined_df = pd.concat([df1, df2, df3], axis=0)

# %%
combined_df = combined_df.reset_index(drop=True)

# %%
combined_df
# Out:
#       customer          st gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# 3                  764586.18%      0.0                 106.0
# 4                  536307.65%  36357.0                  68.0
# ...                       ...      ...                   ...
# 12069             23405.98798  71941.0                  73.0
# 12070             3096.511217  21604.0                  79.0
# 12071             8163.890428      0.0                  85.0
# 12072             7524.442436  21941.0                  96.0
# 12073             2611.836866      0.0                  77.0
#
#       number of open complaints     policy type  vehicle class  \
# 0                        1/0/00   Personal Auto  Four-Door Car
# 1                        1/0/00   Personal Auto  Four-Door Car
# 2                        1/0/00   Personal Auto   Two-Door Car
# 3                        1/0/00  Corporate Auto            SUV
# 4                        1/0/00   Personal Auto  Four-Door Car
# ...                         ...             ...            ...
# 12069                         0   Personal Auto  Four-Door Car
# 12070                         0  Corporate Auto  Four-Door Car
# 12071                         3  Corporate Auto  Four-Door Car
# 12072                         0   Personal Auto  Four-Door Car
# 12073                         0  Corporate Auto   Two-Door Car
#
#        total claim amount
# 0                2.704934
# 1             1131.464935
# 2              566.472247
# 3              529.881344
# 4               17.269323
# ...                   ...
# 12069          198.234764
# 12070          379.200000
# 12071          790.784983
# 12072          691.200000
# 12073          369.600000
#
# [12074 rows x 11 columns]

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12074 entries, 0 to 12073
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   st                         9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer lifetime value    9130 non-null   object
#  5   income                     9137 non-null   float64
#  6   monthly premium auto       9137 non-null   float64
#  7   number of open complaints  9137 non-null   object
#  8   policy type                9137 non-null   object
#  9   vehicle class              9137 non-null   object
#  10  total claim amount         9137 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 1.0+ MB

# %%
combined_df['customer lifetime value']= combined_df ['customer lifetime value'].str.replace("%", " ")

# %%
combined_df ['customer lifetime value']= combined_df ['customer lifetime value'].astype("float64")

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12074 entries, 0 to 12073
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   st                         9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer lifetime value    2060 non-null   float64
#  5   income                     9137 non-null   float64
#  6   monthly premium auto       9137 non-null   float64
#  7   number of open complaints  9137 non-null   object
#  8   policy type                9137 non-null   object
#  9   vehicle class              9137 non-null   object
#  10  total claim amount         9137 non-null   float64
# dtypes: float64(4), object(7)
# memory usage: 1.0+ MB

# %%
combined_df.gender.unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
combined_df.isna().sum()
# Out:
# customer                      2937
# st                            2937
# gender                        3059
# education                     2937
# customer lifetime value      10014
# income                        2937
# monthly premium auto          2937
# number of open complaints     2937
# policy type                   2937
# vehicle class                 2937
# total claim amount            2937
# dtype: int64

# %%
nulls_combined_df = pd.DataFrame(round(combined_df.isna().sum()/len(combined_df),4)*100)
nulls_combined_df = nulls_combined_df.reset_index()
nulls_combined_df.columns = ['header_name', 'percent_nulls']
nulls_combined_df
# Out:
#                   header_name  percent_nulls
# 0                    customer          24.32
# 1                          st          24.32
# 2                      gender          25.34
# 3                   education          24.32
# 4     customer lifetime value          82.94
# 5                      income          24.32
# 6        monthly premium auto          24.32
# 7   number of open complaints          24.32
# 8                 policy type          24.32
# 9               vehicle class          24.32
# 10         total claim amount          24.32

# %%
combined_df = combined_df.dropna(subset = "customer")

# %%
combined_df = combined_df.reset_index(drop=True)

# %%
combined_df.isna().sum()
# Out:
# customer                        0
# st                              0
# gender                        122
# education                       0
# customer lifetime value      7077
# income                          0
# monthly premium auto            0
# number of open complaints       0
# policy type                     0
# vehicle class                   0
# total claim amount              0
# dtype: int64

# %%
mode_value = combined_df['gender'].mode()[0]

# %%
combined_df['gender'].fillna(mode_value, inplace=True)

# %%
combined_df.isna().sum()
# Out:
# customer                        0
# st                              0
# gender                          0
# education                       0
# customer lifetime value      7077
# income                          0
# monthly premium auto            0
# number of open complaints       0
# policy type                     0
# vehicle class                   0
# total claim amount              0
# dtype: int64

# %%
mean_value = combined_df['customer lifetime value'].mean()

# %%
combined_df['customer lifetime value'].fillna(mean_value, inplace=True)

# %%
combined_df.isna().sum()
# Out:
# customer                     0
# st                           0
# gender                       0
# education                    0
# customer lifetime value      0
# income                       0
# monthly premium auto         0
# number of open complaints    0
# policy type                  0
# vehicle class                0
# total claim amount           0
# dtype: int64

# %% [markdown]
# Challenge 2: Structuring Data In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.
# Exercise 1: Clean and Format the Data While the dataset has been partially cleaned and formatted, we still need to perform several data cleaning tasks. Specifically, we need to standardize the column names, clean null values, convert the effective_to_date column to datetime, and extract the months from the dataset and store them in a separate column.
# To accomplish these tasks, we will use the functions created in the previous step to standardize the column names and deal with null values, and then we will apply additional functions to convert the effective_to_date column to datetime and extract the months.
# Save the clean dataset into a csv file.

# %%
import pandas as pd

# %%
df = pd.read_csv ("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv")

# %%
df
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0         Basic   College           2/18/11         Employed      M  ...
# 1         Basic   College           1/18/11       Unemployed      F  ...
# 2         Basic  Bachelor           2/10/11         Employed      M  ...
# 3      Extended   College           1/11/11         Employed      M  ...
# 4       Premium  Bachelor           1/17/11    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor           1/19/11       Unemployed      F  ...
# 10906     Basic   College            1/6/11         Employed      F  ...
# 10907  Extended  Bachelor            2/6/11         Employed      F  ...
# 10908   Premium   College           2/13/11         Employed      F  ...
# 10909     Basic  Bachelor            1/8/11       Unemployed      M  ...
#
#        Number of Open Complaints Number of Policies     Policy Type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              Policy  Renew Offer Type  Sales Channel  Total Claim Amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        Vehicle Class Vehicle Size Vehicle Type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]

# %%
df= df.rename(columns=str.lower)

# %%
def rename_columns(df):
    df.rename (columns = {'effective to date':'datetime'}, inplace=True)
    return df

df = rename_columns(df)
df
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education datetime employmentstatus gender  ...  \
# 0         Basic   College  2/18/11         Employed      M  ...
# 1         Basic   College  1/18/11       Unemployed      F  ...
# 2         Basic  Bachelor  2/10/11         Employed      M  ...
# 3      Extended   College  1/11/11         Employed      M  ...
# 4       Premium  Bachelor  1/17/11    Medical Leave      F  ...
# ...         ...       ...      ...              ...    ...  ...
# 10905   Premium  Bachelor  1/19/11       Unemployed      F  ...
# 10906     Basic   College   1/6/11         Employed      F  ...
# 10907  Extended  Bachelor   2/6/11         Employed      F  ...
# 10908   Premium   College  2/13/11         Employed      F  ...
# 10909     Basic  Bachelor   1/8/11       Unemployed      M  ...
#
#        number of open complaints number of policies     policy type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              policy  renew offer type  sales channel  total claim amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        vehicle class vehicle size vehicle type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]

# %%
df.drop('unnamed: 0', axis=1, inplace=True)

# %%
df = df.reset_index(drop=True)
df
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education datetime employmentstatus gender  income  ...  \
# 0       College  2/18/11         Employed      M   48029  ...
# 1       College  1/18/11       Unemployed      F       0  ...
# 2      Bachelor  2/10/11         Employed      M   22139  ...
# 3       College  1/11/11         Employed      M   49078  ...
# 4      Bachelor  1/17/11    Medical Leave      F   23675  ...
# ...         ...      ...              ...    ...     ...  ...
# 10905  Bachelor  1/19/11       Unemployed      F       0  ...
# 10906   College   1/6/11         Employed      F   61146  ...
# 10907  Bachelor   2/6/11         Employed      F   39837  ...
# 10908   College  2/13/11         Employed      F   64195  ...
# 10909  Bachelor   1/8/11       Unemployed      M       0  ...
#
#       number of open complaints number of policies     policy type  \
# 0                           0.0                  9  Corporate Auto
# 1                           0.0                  1   Personal Auto
# 2                           0.0                  2   Personal Auto
# 3                           0.0                  2  Corporate Auto
# 4                           NaN                  7   Personal Auto
# ...                         ...                ...             ...
# 10905                       NaN                  7   Personal Auto
# 10906                       0.0                  6   Personal Auto
# 10907                       0.0                  2  Corporate Auto
# 10908                       4.0                  6   Personal Auto
# 10909                       0.0                  3   Personal Auto
#
#              policy  renew offer type  sales channel  total claim amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        vehicle class vehicle size vehicle type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 25 columns]

# %%
df.isna().sum()
# Out:
# customer                            0
# state                             631
# customer lifetime value             0
# response                          631
# coverage                            0
# education                           0
# datetime                            0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           633
# months since policy inception       0
# number of open complaints         633
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     622
# vehicle size                      622
# vehicle type                     5482
# dtype: int64

# %%
df = df.dropna(subset = "vehicle type")

# %%
df = df.reset_index(drop=True)

# %%
df.isna().sum()
# Out:
# customer                           0
# state                            313
# customer lifetime value            0
# response                         313
# coverage                           0
# education                          0
# datetime                           0
# employmentstatus                   0
# gender                             0
# income                             0
# location code                      0
# marital status                     0
# monthly premium auto               0
# months since last claim          318
# months since policy inception      0
# number of open complaints        318
# number of policies                 0
# policy type                        0
# policy                             0
# renew offer type                   0
# sales channel                      0
# total claim amount                 0
# vehicle class                    314
# vehicle size                     314
# vehicle type                       0
# dtype: int64

# %%
df = df.dropna(subset = "response")

# %%
df = df.reset_index(drop=True)

# %%
df.isna().sum()
# Out:
# customer                           0
# state                              0
# customer lifetime value            0
# response                           0
# coverage                           0
# education                          0
# datetime                           0
# employmentstatus                   0
# gender                             0
# income                             0
# location code                      0
# marital status                     0
# monthly premium auto               0
# months since last claim          292
# months since policy inception      0
# number of open complaints        292
# number of policies                 0
# policy type                        0
# policy                             0
# renew offer type                   0
# sales channel                      0
# total claim amount                 0
# vehicle class                    296
# vehicle size                     296
# vehicle type                       0
# dtype: int64

# %%
#df = df.dropna(subset = "number of open complaints")

# %%
#df = df.reset_index(drop=True)

# %%
#df.isna().sum()

# %%
mode_value1 = df['vehicle class'].mode()[0]

# %%
df['vehicle class'].fillna(mode_value1, inplace=True)

# %%
df.isna().sum()
# Out:
# customer                           0
# state                              0
# customer lifetime value            0
# response                           0
# coverage                           0
# education                          0
# datetime                           0
# employmentstatus                   0
# gender                             0
# income                             0
# location code                      0
# marital status                     0
# monthly premium auto               0
# months since last claim          292
# months since policy inception      0
# number of open complaints        292
# number of policies                 0
# policy type                        0
# policy                             0
# renew offer type                   0
# sales channel                      0
# total claim amount                 0
# vehicle class                      0
# vehicle size                     296
# vehicle type                       0
# dtype: int64

# %%
mode_value2 = df['vehicle size'].mode()[0]

# %%
df['vehicle size'].fillna(mode_value2, inplace=True)

# %%
df.isna().sum()
# Out:
# customer                           0
# state                              0
# customer lifetime value            0
# response                           0
# coverage                           0
# education                          0
# datetime                           0
# employmentstatus                   0
# gender                             0
# income                             0
# location code                      0
# marital status                     0
# monthly premium auto               0
# months since last claim          292
# months since policy inception      0
# number of open complaints        292
# number of policies                 0
# policy type                        0
# policy                             0
# renew offer type                   0
# sales channel                      0
# total claim amount                 0
# vehicle class                      0
# vehicle size                       0
# vehicle type                       0
# dtype: int64

# %%
#df['datetime'] = pd.to_datetime(df['datetime'])

# %%
#df['month'] = df['datetime'].dt.month
#df

# %%
df
# Out:
#      customer       state  customer lifetime value response  coverage  \
# 0     LZ68649  Washington             14947.917300       No     Basic
# 1     XL78013      Oregon             22332.439460      Yes  Extended
# 2     HG93801     Arizona              5154.764074       No  Extended
# 3     KR82385  California              5454.587929       No     Basic
# 4     FH51383  California              5326.677654       No     Basic
# ...       ...         ...                      ...      ...       ...
# 5110  SU71163     Arizona              2771.663013       No     Basic
# 5111  QI63521      Nevada             19228.463620       No     Basic
# 5112  FE99816      Nevada             15563.369440       No   Premium
# 5113  KX53892      Oregon              5259.444853       No     Basic
# 5114  WA60547  California             11971.977650       No   Premium
#
#                  education datetime employmentstatus gender  income  ...  \
# 0                 Bachelor  2/10/11         Employed      M   22139  ...
# 1                  College  1/11/11         Employed      M   49078  ...
# 2     High School or Below   1/2/11         Employed      M   82730  ...
# 3                   Master  1/26/11         Employed      M   66334  ...
# 4     High School or Below   2/7/11         Employed      F   76717  ...
# ...                    ...      ...              ...    ...     ...  ...
# 5110               College   1/7/11         Employed      M   59855  ...
# 5111  High School or Below  2/24/11       Unemployed      M       0  ...
# 5112              Bachelor  1/19/11       Unemployed      F       0  ...
# 5113               College   1/6/11         Employed      F   61146  ...
# 5114               College  2/13/11         Employed      F   64195  ...
#
#      number of open complaints number of policies     policy type  \
# 0                          0.0                  2   Personal Auto
# 1                          0.0                  2  Corporate Auto
# 2                          0.0                  1  Corporate Auto
# 3                          0.0                  4   Personal Auto
# 4                          0.0                  6   Personal Auto
# ...                        ...                ...             ...
# 5110                       4.0                  1   Personal Auto
# 5111                       0.0                  2   Personal Auto
# 5112                       NaN                  7   Personal Auto
# 5113                       0.0                  6   Personal Auto
# 5114                       4.0                  6   Personal Auto
#
#             policy  renew offer type  sales channel  total claim amount  \
# 0      Personal L3            Offer3    Call Center          480.000000
# 1     Corporate L3            Offer2         Branch          484.013411
# 2     Corporate L3            Offer2         Branch          442.521087
# 3      Personal L3            Offer4    Call Center          331.200000
# 4      Personal L3            Offer4    Call Center          300.528579
# ...            ...               ...            ...                 ...
# 5110   Personal L2            Offer2         Branch          355.200000
# 5111   Personal L2            Offer1         Branch          897.600000
# 5112   Personal L1            Offer3            Web         1214.400000
# 5113   Personal L3            Offer2         Branch          273.018929
# 5114   Personal L1            Offer1         Branch          618.288849
#
#       vehicle class vehicle size vehicle type
# 0               SUV      Medsize            A
# 1     Four-Door Car      Medsize            A
# 2               SUV        Large            A
# 3      Two-Door Car      Medsize            A
# 4      Two-Door Car        Large            A
# ...             ...          ...          ...
# 5110   Two-Door Car      Medsize            A
# 5111     Luxury SUV      Medsize            A
# 5112     Luxury Car      Medsize            A
# 5113  Four-Door Car      Medsize            A
# 5114            SUV      Medsize            A
#
# [5115 rows x 25 columns]

# %%
df
# Out:
#      customer       state  customer lifetime value response  coverage  \
# 0     LZ68649  Washington             14947.917300       No     Basic
# 1     XL78013      Oregon             22332.439460      Yes  Extended
# 2     HG93801     Arizona              5154.764074       No  Extended
# 3     KR82385  California              5454.587929       No     Basic
# 4     FH51383  California              5326.677654       No     Basic
# ...       ...         ...                      ...      ...       ...
# 5110  SU71163     Arizona              2771.663013       No     Basic
# 5111  QI63521      Nevada             19228.463620       No     Basic
# 5112  FE99816      Nevada             15563.369440       No   Premium
# 5113  KX53892      Oregon              5259.444853       No     Basic
# 5114  WA60547  California             11971.977650       No   Premium
#
#                  education datetime employmentstatus gender  income  ...  \
# 0                 Bachelor  2/10/11         Employed      M   22139  ...
# 1                  College  1/11/11         Employed      M   49078  ...
# 2     High School or Below   1/2/11         Employed      M   82730  ...
# 3                   Master  1/26/11         Employed      M   66334  ...
# 4     High School or Below   2/7/11         Employed      F   76717  ...
# ...                    ...      ...              ...    ...     ...  ...
# 5110               College   1/7/11         Employed      M   59855  ...
# 5111  High School or Below  2/24/11       Unemployed      M       0  ...
# 5112              Bachelor  1/19/11       Unemployed      F       0  ...
# 5113               College   1/6/11         Employed      F   61146  ...
# 5114               College  2/13/11         Employed      F   64195  ...
#
#      number of open complaints number of policies     policy type  \
# 0                          0.0                  2   Personal Auto
# 1                          0.0                  2  Corporate Auto
# 2                          0.0                  1  Corporate Auto
# 3                          0.0                  4   Personal Auto
# 4                          0.0                  6   Personal Auto
# ...                        ...                ...             ...
# 5110                       4.0                  1   Personal Auto
# 5111                       0.0                  2   Personal Auto
# 5112                       NaN                  7   Personal Auto
# 5113                       0.0                  6   Personal Auto
# 5114                       4.0                  6   Personal Auto
#
#             policy  renew offer type  sales channel  total claim amount  \
# 0      Personal L3            Offer3    Call Center          480.000000
# 1     Corporate L3            Offer2         Branch          484.013411
# 2     Corporate L3            Offer2         Branch          442.521087
# 3      Personal L3            Offer4    Call Center          331.200000
# 4      Personal L3            Offer4    Call Center          300.528579
# ...            ...               ...            ...                 ...
# 5110   Personal L2            Offer2         Branch          355.200000
# 5111   Personal L2            Offer1         Branch          897.600000
# 5112   Personal L1            Offer3            Web         1214.400000
# 5113   Personal L3            Offer2         Branch          273.018929
# 5114   Personal L1            Offer1         Branch          618.288849
#
#       vehicle class vehicle size vehicle type
# 0               SUV      Medsize            A
# 1     Four-Door Car      Medsize            A
# 2               SUV        Large            A
# 3      Two-Door Car      Medsize            A
# 4      Two-Door Car        Large            A
# ...             ...          ...          ...
# 5110   Two-Door Car      Medsize            A
# 5111     Luxury SUV      Medsize            A
# 5112     Luxury Car      Medsize            A
# 5113  Four-Door Car      Medsize            A
# 5114            SUV      Medsize            A
#
# [5115 rows x 25 columns]

# %%
df['datetime'] = pd.to_datetime(df['datetime'], format='%m/%d/%y')

# %%
df['month'] = df['datetime'].dt.strftime('%m')

# %%
df['datetime'] = df['datetime'].dt.strftime('%m/%d/%y')

# %%
df
# Out:
#      customer       state  customer lifetime value response  coverage  \
# 0     LZ68649  Washington             14947.917300       No     Basic
# 1     XL78013      Oregon             22332.439460      Yes  Extended
# 2     HG93801     Arizona              5154.764074       No  Extended
# 3     KR82385  California              5454.587929       No     Basic
# 4     FH51383  California              5326.677654       No     Basic
# ...       ...         ...                      ...      ...       ...
# 5110  SU71163     Arizona              2771.663013       No     Basic
# 5111  QI63521      Nevada             19228.463620       No     Basic
# 5112  FE99816      Nevada             15563.369440       No   Premium
# 5113  KX53892      Oregon              5259.444853       No     Basic
# 5114  WA60547  California             11971.977650       No   Premium
#
#                  education  datetime employmentstatus gender  income  ...  \
# 0                 Bachelor  02/10/11         Employed      M   22139  ...
# 1                  College  01/11/11         Employed      M   49078  ...
# 2     High School or Below  01/02/11         Employed      M   82730  ...
# 3                   Master  01/26/11         Employed      M   66334  ...
# 4     High School or Below  02/07/11         Employed      F   76717  ...
# ...                    ...       ...              ...    ...     ...  ...
# 5110               College  01/07/11         Employed      M   59855  ...
# 5111  High School or Below  02/24/11       Unemployed      M       0  ...
# 5112              Bachelor  01/19/11       Unemployed      F       0  ...
# 5113               College  01/06/11         Employed      F   61146  ...
# 5114               College  02/13/11         Employed      F   64195  ...
#
#      number of policies     policy type        policy  renew offer type  \
# 0                     2   Personal Auto   Personal L3            Offer3
# 1                     2  Corporate Auto  Corporate L3            Offer2
# 2                     1  Corporate Auto  Corporate L3            Offer2
# 3                     4   Personal Auto   Personal L3            Offer4
# 4                     6   Personal Auto   Personal L3            Offer4
# ...                 ...             ...           ...               ...
# 5110                  1   Personal Auto   Personal L2            Offer2
# 5111                  2   Personal Auto   Personal L2            Offer1
# 5112                  7   Personal Auto   Personal L1            Offer3
# 5113                  6   Personal Auto   Personal L3            Offer2
# 5114                  6   Personal Auto   Personal L1            Offer1
#
#       sales channel  total claim amount  vehicle class vehicle size  \
# 0       Call Center          480.000000            SUV      Medsize
# 1            Branch          484.013411  Four-Door Car      Medsize
# 2            Branch          442.521087            SUV        Large
# 3       Call Center          331.200000   Two-Door Car      Medsize
# 4       Call Center          300.528579   Two-Door Car        Large
# ...             ...                 ...            ...          ...
# 5110         Branch          355.200000   Two-Door Car      Medsize
# 5111         Branch          897.600000     Luxury SUV      Medsize
# 5112            Web         1214.400000     Luxury Car      Medsize
# 5113         Branch          273.018929  Four-Door Car      Medsize
# 5114         Branch          618.288849            SUV      Medsize
#
#      vehicle type month
# 0               A    02
# 1               A    01
# 2               A    01
# 3               A    01
# 4               A    02
# ...           ...   ...
# 5110            A    01
# 5111            A    02
# 5112            A    01
# 5113            A    01
# 5114            A    02
#
# [5115 rows x 26 columns]

# %% [markdown]
# Create a summary tableshowing the total re venue for each sales channel (branch, call center, web, and mail).
# Round the total_claim_amount to 2 decimal points. Analyze the resulting table to draw insights.

# %%
df['total claim amount'] = df['total claim amount'].round(2)

# Grouping DataFrame by 'sales_channel' and calculate the sum of 'total_claim_amount' for each channel
summary_table = df.groupby('sales channel')['total claim amount'].sum().reset_index()

print(summary_table)
# Out:
#   sales channel  total claim amount
# 0         Agent           845755.30
# 1        Branch           613483.14
# 2   Call Center           455461.01
# 3           Web           335306.76

# %% [markdown]
# Create a pivot table showing the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
pivot_table = pd.pivot_table(df, values='customer lifetime value', index='gender', columns='education', aggfunc='mean')


print(pivot_table)
# Out:
# education     Bachelor      College       Doctor  High School or Below  \
# gender
# F          8035.441942  7768.048550  8290.519914           8566.247286
# M          7997.376076  8157.069516  7510.332314           8018.334582
#
# education       Master
# gender
# F          8383.386846
# M          8008.027635

# %% [markdown]
# Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %%
df['complaints'] = pd.to_datetime(df['complaint_date'])

 Extract the month from the 'complaint_date' column
df['month'] = df['complaint_date'].dt.strftime('%B')

# Group the DataFrame by 'policy_type' and 'month' and calculate the count of complaints
#summary_table = df.groupby(['policy type', 'month']).size().reset_index(name='num_complaints')

# Display the summary table in long format
#print(summary_table)
# Out:
#   Cell In[59], line 3
#     Extract the month from the 'complaint_date' column
#     ^
# IndentationError: unexpected indent
