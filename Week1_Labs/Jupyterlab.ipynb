# %% [markdown]
# # HOLIDAY PLANS

# %% [markdown]
# The purpose of this notebook is to introduce someone to a beautiful holday in the Philippines.

# %%
vacation_plan = input ("please write your name: ")
print ("Holiday plans for", vacation_plan)
# Out:
# please write your name: Sofia
# Holiday plans for Sofia

# %% [markdown]
# ![1BF11B8F-FE3C-4710-B67C-BA06C03464F5.JPG](attachment:1BF11B8F-FE3C-4710-B67C-BA06C03464F5.JPG)

# %% [markdown]
# ![Dao.jpeg](attachment:Dao.jpeg)

# %% [markdown]
# ![Palawan.jpeg](attachment:Palawan.jpeg)

# %% [markdown]
# ![Boracay.jpeg](attachment:Boracay.jpeg)

# %% [markdown]
# - # Parasailing in Boracay
# - ## Kayaking in Palawan
# - ### Chasing waterfalls in Cebu

# %% [markdown]
# [Link Text](https://www.youtube.com/watch?v=b7LSsKsJGHY)

# %% [markdown]
# [Link Text](https://www.youtube.com/watch?v=bmHrdsNvsYY)

# %% [markdown]
# [Link Text](https://www.youtube.com/watch?v=_l7orhrUQaQ)

# %% [markdown]
# Annotation: I used this command to attach youtube links
# [Link Text](YouTube_URL)
